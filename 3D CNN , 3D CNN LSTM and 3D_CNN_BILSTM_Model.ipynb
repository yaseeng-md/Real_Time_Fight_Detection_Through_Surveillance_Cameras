# %%
import numpy as np 
import cv2
import os 
import pandas as pd
import matplotlib.pylab as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical,plot_model
import tqdm
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import categorical_crossentropy
# Out:
# 2024-11-08 18:09:12.279310: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-11-08 18:09:12.348415: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-08 18:09:12.406708: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-08 18:09:12.423045: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-08 18:09:12.473497: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-08 18:09:15.695648: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
DATA_DIR = "fight-detection-surv-dataset"
CLASS_NAMES = ["fight","noFight"]
SEQUENCE_LENGTH = 8
IMG_HEIGHT , IMG_WIDTH = 150,150
BATCHES = 32
CHANNELS = 3
INPUT_SHAPE = (SEQUENCE_LENGTH,IMG_HEIGHT,IMG_WIDTH,CHANNELS)
LABEL_POSITION = (10, 30) #(x,y)
LABEL_FONT = cv2.FONT_HERSHEY_SIMPLEX
LABEL_FONT_SIZE = 0.8
LABEL_COLOR = (0, 0, 255)  # White color in BGR
LABEL_THICKNESS = 2

# %%
def create_dataset():
    features = []
    labels = []
    video_file_paths = []
    for class_index,class_name in enumerate(CLASS_NAMES):
        print(class_name)
        files_path = os.listdir(os.path.join(DATA_DIR,class_name))
        for file_name in files_path:
            video_file_path = os.path.join(DATA_DIR,class_name,file_name)
            frames = frame_extraction(video_file_path)
            if len(frames) == SEQUENCE_LENGTH:
                features.append(frames)
                labels.append(class_index)
                video_file_paths.append(video_file_path)
    features = np.asarray(features)
    lables = np.array(labels)
    return features,labels,video_file_paths

# %%
def frame_extraction(video_path):
    frames_list = []
    video_reader = cv2.VideoCapture(video_path)
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))
    skip_frames_window = max(int(video_frames_count/SEQUENCE_LENGTH),1)
    for frame_counter in range(SEQUENCE_LENGTH):
        video_reader.set(cv2.CAP_PROP_POS_FRAMES,frame_counter*skip_frames_window)
        success,frame = video_reader.read()
        if not success:
            break
        resized_frame = cv2.resize(frame,(IMG_HEIGHT,IMG_WIDTH))
        normalized_frame = resized_frame / 255
        frames_list.append(normalized_frame)
    video_reader.release()
    return np.asarray(frames_list)

# %%
features,labels,video_file_paths = create_dataset()
# Out:
# fight
# noFight

# %%
encoded_labels = tf.keras.utils.to_categorical(labels)

# %%
from sklearn.model_selection import train_test_split
features_train,features_test,labels_train,labels_test = train_test_split(features,encoded_labels,test_size=0.3)

# %%
labels_train.shape
# Out:
# (210, 2)

# %%
ThreeD_model = Sequential([  
    InputLayer(shape=(8,150,150,3)),
    
    Conv3D(filters=32,kernel_size=(2,2,2),activation="relu"),
    MaxPooling3D(pool_size=(2, 2, 2)),
    
    Conv3D(filters=64,kernel_size=(2,2,2),activation="relu"),
    MaxPooling3D(pool_size=(2, 2, 2)),
    
    # Conv3D(filters=128,kernel_size=(3,3,3),padding="same",activation="relu"),
    # MaxPooling3D(pool_size=(3, 3, 3)),

    Flatten(),
    
    Dense(units = 512, activation="relu"),
    Dense(units=2,activation="sigmoid")
])
ThreeD_model.compile(loss=categorical_crossentropy,optimizer=Adam(), metrics=['accuracy'])
# plot_model(ThreeD_model, to_file='3D_CNN_Model.png', show_shapes=True, show_layer_names=True)

# %%
ThreeD_model_history = ThreeD_model.fit(x = features_train,y = labels_train,epochs = 30, validation_data = (features_test,labels_test))
ThreeD_model.save("3D_CNN_Model.keras")
# Out:
# Epoch 1/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 709ms/step - accuracy: 0.4951 - loss: 8.1976 - val_accuracy: 0.4778 - val_loss: 0.7396
# Epoch 2/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 629ms/step - accuracy: 0.5947 - loss: 0.6844 - val_accuracy: 0.5556 - val_loss: 0.6676
# Epoch 3/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 637ms/step - accuracy: 0.7285 - loss: 0.5677 - val_accuracy: 0.6778 - val_loss: 0.6745
# Epoch 4/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 641ms/step - accuracy: 0.7861 - loss: 0.4836 - val_accuracy: 0.6556 - val_loss: 0.6652
# Epoch 5/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 625ms/step - accuracy: 0.9117 - loss: 0.3684 - val_accuracy: 0.5667 - val_loss: 0.7676
# Epoch 6/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 633ms/step - accuracy: 0.8446 - loss: 0.2890 - val_accuracy: 0.6556 - val_loss: 0.6553
# Epoch 7/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 640ms/step - accuracy: 0.9388 - loss: 0.2126 - val_accuracy: 0.6667 - val_loss: 0.6505
# Epoch 8/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 643ms/step - accuracy: 0.9741 - loss: 0.1313 - val_accuracy: 0.6222 - val_loss: 0.7281
# Epoch 9/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 645ms/step - accuracy: 0.9970 - loss: 0.0663 - val_accuracy: 0.7000 - val_loss: 0.7605
# Epoch 10/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 674ms/step - accuracy: 0.9843 - loss: 0.0677 - val_accuracy: 0.7111 - val_loss: 0.8335
# Epoch 11/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 648ms/step - accuracy: 0.9883 - loss: 0.0355 - val_accuracy: 0.7333 - val_loss: 0.8587
# Epoch 12/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 666ms/step - accuracy: 1.0000 - loss: 0.0227 - val_accuracy: 0.7778 - val_loss: 0.9213
# Epoch 13/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 631ms/step - accuracy: 0.9931 - loss: 0.0241 - val_accuracy: 0.7667 - val_loss: 0.9401
# Epoch 14/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 627ms/step - accuracy: 1.0000 - loss: 0.0230 - val_accuracy: 0.7000 - val_loss: 1.4966
# Epoch 15/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 642ms/step - accuracy: 0.9837 - loss: 0.0398 - val_accuracy: 0.7444 - val_loss: 0.9677
# Epoch 16/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 635ms/step - accuracy: 0.9931 - loss: 0.0240 - val_accuracy: 0.6667 - val_loss: 1.0337
# Epoch 17/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 631ms/step - accuracy: 1.0000 - loss: 0.0204 - val_accuracy: 0.7000 - val_loss: 1.5580
# Epoch 18/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 634ms/step - accuracy: 1.0000 - loss: 0.0223 - val_accuracy: 0.6222 - val_loss: 1.0610
# Epoch 19/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 631ms/step - accuracy: 0.9988 - loss: 0.0225 - val_accuracy: 0.7333 - val_loss: 1.2200
# Epoch 20/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 630ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 0.7111 - val_loss: 1.0851
# Epoch 21/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 631ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.7111 - val_loss: 1.4111
# Epoch 22/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 630ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.7444 - val_loss: 1.1506
# Epoch 23/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 625ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.7444 - val_loss: 1.2172
# Epoch 24/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 656ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.7333 - val_loss: 1.3887
# Epoch 25/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 630ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.7444 - val_loss: 1.2808
# Epoch 26/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 632ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.7556 - val_loss: 1.2646
# Epoch 27/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 636ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.7444 - val_loss: 1.3221
# Epoch 28/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 638ms/step - accuracy: 1.0000 - loss: 9.1117e-04 - val_accuracy: 0.7444 - val_loss: 1.3781
# Epoch 29/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 638ms/step - accuracy: 1.0000 - loss: 8.7399e-04 - val_accuracy: 0.7444 - val_loss: 1.3627
# Epoch 30/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 626ms/step - accuracy: 1.0000 - loss: 6.4552e-04 - val_accuracy: 0.7444 - val_loss: 1.3395

# %%
# plot_model(ThreeD_model, to_file='3D_CNN_Model.png', show_shapes=True, show_layer_names=True)
ThreeD_history = pd.DataFrame(ThreeD_model_history.history)
ThreeD_history.to_csv("ThreeD_model_history.csv")

# %%
ThreeD_CNN_model = Sequential([  
    InputLayer(shape=(8,150,150,3)),
    
    Conv3D(filters=32, kernel_size=(2, 2, 2), activation="relu"),
    MaxPooling3D(pool_size=(2,2,2)),
    Conv3D(filters=64, kernel_size=(2,2,2), activation="relu"),
    MaxPooling3D(pool_size=(2,2,2)),
    
    TimeDistributed(Flatten()),
    LSTM(units=64, return_sequences=True, activation="relu"),
    LSTM(units=32, return_sequences=False, activation="relu"),
    
    # Flatten(),
    
    Dense(units=512, activation="relu"),
    Dense(units=2, activation="sigmoid")
])

ThreeD_CNN_model.compile(loss=categorical_crossentropy, optimizer=Adam(), metrics=['accuracy'])
# plot_model(ThreeD_CNN_model,to_file = "3D_CNN_LSTM_Model.png",show_shapes=True, show_layer_names=True)

# %%
ThreeD_CNN_model_history = ThreeD_CNN_model.fit(x = features_train,y = labels_train,epochs = 30,validation_data = (features_test,labels_test))
# Out:
# Epoch 1/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 590ms/step - accuracy: 0.5262 - loss: 0.7041 - val_accuracy: 0.5889 - val_loss: 0.6915
# Epoch 2/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 540ms/step - accuracy: 0.6605 - loss: 0.6896 - val_accuracy: 0.5889 - val_loss: 0.6853
# Epoch 3/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 532ms/step - accuracy: 0.6200 - loss: 0.6792 - val_accuracy: 0.5556 - val_loss: 0.6819
# Epoch 4/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 532ms/step - accuracy: 0.6644 - loss: 0.6437 - val_accuracy: 0.4889 - val_loss: 0.7175
# Epoch 5/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 528ms/step - accuracy: 0.5673 - loss: 0.6628 - val_accuracy: 0.6111 - val_loss: 0.6520
# Epoch 6/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 548ms/step - accuracy: 0.7807 - loss: 0.5544 - val_accuracy: 0.6444 - val_loss: 0.6398
# Epoch 7/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 532ms/step - accuracy: 0.8312 - loss: 0.4146 - val_accuracy: 0.6778 - val_loss: 0.7018
# Epoch 8/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 529ms/step - accuracy: 0.9100 - loss: 0.2508 - val_accuracy: 0.6778 - val_loss: 0.7457
# Epoch 9/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 531ms/step - accuracy: 0.9431 - loss: 0.1803 - val_accuracy: 0.7333 - val_loss: 1.0978
# Epoch 10/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 544ms/step - accuracy: 0.9681 - loss: 0.1124 - val_accuracy: 0.6889 - val_loss: 0.9627
# Epoch 11/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 531ms/step - accuracy: 0.9634 - loss: 0.1488 - val_accuracy: 0.7111 - val_loss: 0.8389
# Epoch 12/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 543ms/step - accuracy: 0.9590 - loss: 0.1071 - val_accuracy: 0.6222 - val_loss: 1.4610
# Epoch 13/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 534ms/step - accuracy: 0.9887 - loss: 0.0600 - val_accuracy: 0.7000 - val_loss: 1.2981
# Epoch 14/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 539ms/step - accuracy: 0.9814 - loss: 0.0417 - val_accuracy: 0.7222 - val_loss: 1.4789
# Epoch 15/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 537ms/step - accuracy: 0.9925 - loss: 0.0146 - val_accuracy: 0.7111 - val_loss: 1.8698
# Epoch 16/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 532ms/step - accuracy: 0.9933 - loss: 0.0100 - val_accuracy: 0.7000 - val_loss: 2.7634
# Epoch 17/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 536ms/step - accuracy: 1.0000 - loss: 0.0149 - val_accuracy: 0.6000 - val_loss: 2.4829
# Epoch 18/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 563ms/step - accuracy: 0.9964 - loss: 0.0079 - val_accuracy: 0.6778 - val_loss: 2.6189
# Epoch 19/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 541ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.7000 - val_loss: 3.0551
# Epoch 20/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 533ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.6778 - val_loss: 3.1874
# Epoch 21/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 537ms/step - accuracy: 1.0000 - loss: 2.0050e-04 - val_accuracy: 0.6778 - val_loss: 3.2787
# Epoch 22/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 544ms/step - accuracy: 1.0000 - loss: 1.4022e-04 - val_accuracy: 0.6778 - val_loss: 3.3715
# Epoch 23/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 540ms/step - accuracy: 1.0000 - loss: 1.0892e-04 - val_accuracy: 0.6778 - val_loss: 3.4890
# Epoch 24/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 530ms/step - accuracy: 1.0000 - loss: 8.9387e-05 - val_accuracy: 0.6778 - val_loss: 3.5920
# Epoch 25/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 542ms/step - accuracy: 1.0000 - loss: 3.7533e-05 - val_accuracy: 0.6778 - val_loss: 3.6659
# Epoch 26/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 532ms/step - accuracy: 1.0000 - loss: 3.3989e-05 - val_accuracy: 0.6778 - val_loss: 3.7186
# Epoch 27/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 585ms/step - accuracy: 1.0000 - loss: 2.7836e-05 - val_accuracy: 0.6778 - val_loss: 3.7506
# Epoch 28/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 539ms/step - accuracy: 1.0000 - loss: 4.2911e-05 - val_accuracy: 0.6778 - val_loss: 3.7834
# Epoch 29/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 549ms/step - accuracy: 1.0000 - loss: 3.3286e-05 - val_accuracy: 0.6778 - val_loss: 3.8070
# Epoch 30/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 523ms/step - accuracy: 1.0000 - loss: 2.2630e-05 - val_accuracy: 0.6778 - val_loss: 3.8288

# %%
ThreeD_CNN_model.save("3D_CNN_LSTM_Model.keras")

# %%
ThreeD_CNN_lstm_model_train_accuracy = ThreeD_CNN_model_history.history["accuracy"]
ThreeD_CNN_lstm_model_train_loss = ThreeD_CNN_model_history.history["loss"]
ThreeD_CNN_lstm_model_val_accuracy = ThreeD_CNN_model_history.history["val_accuracy"]
ThreeD_CNN_lstm_model_val_loss = ThreeD_CNN_model_history.history["val_loss"]

import pandas as pd
ThreeD_CNN_lstm_model_history = pd.DataFrame(ThreeD_CNN_model_history.history)
ThreeD_CNN_lstm_model_history.to_csv(path_or_buf = "3D_CNN_LSTM_History.csv")

# %%
plt.plot(ThreeD_CNN_model_history.epoch,ThreeD_CNN_lstm_model_train_accuracy,label = "Train Accuracy")
plt.plot(ThreeD_CNN_model_history.epoch,ThreeD_CNN_lstm_model_val_accuracy, label = "Validation Accuracy")
plt.legend()
plt.show()

# %%
plt.plot(ThreeD_CNN_model_history.epoch,ThreeD_CNN_lstm_model_train_loss,label = "Train Loss")
plt.plot(ThreeD_CNN_model_history.epoch,ThreeD_CNN_lstm_model_val_loss, label = "Validation Loss")
plt.legend()
plt.show()

# %%
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
ThreeD_CNN_bilstm_model = Sequential([  
    InputLayer(shape=(8,150,150,3)),
    
    Conv3D(filters=32, kernel_size=(2, 2, 2), activation="relu"),
    MaxPooling3D(pool_size=(2,2,2)),
    Conv3D(filters=64, kernel_size=(2,2,2), activation="relu"),
    MaxPooling3D(pool_size=(2,2,2)),
    
    TimeDistributed(Flatten()),
    Bidirectional(LSTM(units=64, return_sequences=True, activation="relu")),
    Bidirectional(LSTM(units=32, return_sequences=False, activation="relu")),
    
    # Flatten(),
    
    Dense(units=512, activation="relu"),
    Dense(units=2, activation="sigmoid")
])

ThreeD_CNN_bilstm_model.compile(loss=categorical_crossentropy, optimizer=Adam(), metrics=['accuracy'])
ThreeD_CNN_bilstm_model_history = ThreeD_CNN_bilstm_model.fit(x = features_train,y = labels_train,epochs = 30,validation_data = (features_test,labels_test))
# Out:
# 2024-11-08 18:14:23.560179: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:266] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# Epoch 1/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 842ms/step - accuracy: 0.4774 - loss: 0.7009 - val_accuracy: 0.5111 - val_loss: 0.6920
# Epoch 2/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 732ms/step - accuracy: 0.5046 - loss: 0.6888 - val_accuracy: 0.5111 - val_loss: 0.6906
# Epoch 3/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 724ms/step - accuracy: 0.5160 - loss: 0.6750 - val_accuracy: 0.5778 - val_loss: 0.7285
# Epoch 4/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 727ms/step - accuracy: 0.6457 - loss: 0.6340 - val_accuracy: 0.6111 - val_loss: 0.7574
# Epoch 5/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 728ms/step - accuracy: 0.7669 - loss: 0.5921 - val_accuracy: 0.5444 - val_loss: 1.0183
# Epoch 6/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 720ms/step - accuracy: 0.7127 - loss: 0.5958 - val_accuracy: 0.6333 - val_loss: 0.8143
# Epoch 7/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 715ms/step - accuracy: 0.7998 - loss: 0.4971 - val_accuracy: 0.5778 - val_loss: 0.7674
# Epoch 8/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 734ms/step - accuracy: 0.8071 - loss: 0.3938 - val_accuracy: 0.5333 - val_loss: 1.0417
# Epoch 9/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 723ms/step - accuracy: 0.8583 - loss: 0.3144 - val_accuracy: 0.6333 - val_loss: 0.9049
# Epoch 10/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 725ms/step - accuracy: 0.9416 - loss: 0.1671 - val_accuracy: 0.6778 - val_loss: 1.0110
# Epoch 11/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 723ms/step - accuracy: 0.9722 - loss: 0.0948 - val_accuracy: 0.6667 - val_loss: 1.2771
# Epoch 12/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 731ms/step - accuracy: 0.9876 - loss: 0.0494 - val_accuracy: 0.6667 - val_loss: 1.1790
# Epoch 13/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 718ms/step - accuracy: 0.9541 - loss: 0.1355 - val_accuracy: 0.6667 - val_loss: 1.0012
# Epoch 14/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 723ms/step - accuracy: 0.9559 - loss: 0.1311 - val_accuracy: 0.6556 - val_loss: 1.0507
# Epoch 15/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 728ms/step - accuracy: 0.9444 - loss: 0.1281 - val_accuracy: 0.6333 - val_loss: 1.3932
# Epoch 16/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 741ms/step - accuracy: 0.9800 - loss: 0.0963 - val_accuracy: 0.6667 - val_loss: 1.3803
# Epoch 17/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 753ms/step - accuracy: 0.9815 - loss: 0.0470 - val_accuracy: 0.6556 - val_loss: 1.7108
# Epoch 18/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 765ms/step - accuracy: 0.9504 - loss: 0.1290 - val_accuracy: 0.6667 - val_loss: 1.4627
# Epoch 19/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 754ms/step - accuracy: 0.9934 - loss: 0.0377 - val_accuracy: 0.6444 - val_loss: 1.4285
# Epoch 20/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 750ms/step - accuracy: 0.9963 - loss: 0.0331 - val_accuracy: 0.7000 - val_loss: 1.3549
# Epoch 21/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 758ms/step - accuracy: 0.9814 - loss: 0.0296 - val_accuracy: 0.6556 - val_loss: 1.9331
# Epoch 22/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 765ms/step - accuracy: 0.9955 - loss: 0.0110 - val_accuracy: 0.7111 - val_loss: 1.9192
# Epoch 23/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 741ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.6778 - val_loss: 2.2248
# Epoch 24/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 766ms/step - accuracy: 1.0000 - loss: 0.0072 - val_accuracy: 0.6333 - val_loss: 2.9128
# Epoch 25/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 741ms/step - accuracy: 1.0000 - loss: 9.6211e-04 - val_accuracy: 0.6556 - val_loss: 2.7816
# Epoch 26/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 738ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.6556 - val_loss: 2.9561
# Epoch 27/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 759ms/step - accuracy: 1.0000 - loss: 7.7048e-04 - val_accuracy: 0.6444 - val_loss: 3.1124
# Epoch 28/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 750ms/step - accuracy: 1.0000 - loss: 3.9099e-04 - val_accuracy: 0.6444 - val_loss: 3.2287
# Epoch 29/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 791ms/step - accuracy: 1.0000 - loss: 1.1657e-04 - val_accuracy: 0.6444 - val_loss: 3.3081
# Epoch 30/30
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 759ms/step - accuracy: 1.0000 - loss: 6.7089e-05 - val_accuracy: 0.6444 - val_loss: 3.3529

# %%
ThreeD_CNN_bilstm_model_train_accuracy = ThreeD_CNN_bilstm_model_history.history["accuracy"]
ThreeD_CNN_bilstm_model_train_loss = ThreeD_CNN_bilstm_model_history.history["loss"]
ThreeD_CNN_bilstm_model_val_accuracy = ThreeD_CNN_bilstm_model_history.history["val_accuracy"]
ThreeD_CNN_bilstm_model_val_loss = ThreeD_CNN_bilstm_model_history.history["val_loss"]

import pandas as pd
ThreeD_CNN_lstm_model_history = pd.DataFrame(ThreeD_CNN_bilstm_model_history.history)
ThreeD_CNN_lstm_model_history.to_csv(path_or_buf = "3D_CNN_BILSTM_History.csv")

# %%
plt.plot(ThreeD_CNN_bilstm_model_train_accuracy,label = "Train Accuracy")
plt.plot(ThreeD_CNN_bilstm_model_val_accuracy, label = "Validation Accuracy")
plt.legend()
plt.show()

# %%
plt.plot(ThreeD_CNN_bilstm_model_train_loss,label = "Train loss")
plt.plot(ThreeD_CNN_bilstm_model_val_loss, label = "Validation loss")
plt.legend()
plt.show()
